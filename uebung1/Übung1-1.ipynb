# %% [markdown]
# # Übung 1

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Download data from internet and load into a pandas dataframe

# %%
url='https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'
cols=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','TGT']
boston=pd.read_csv(url,sep=' ',skipinitialspace=True,header=None,names=cols,index_col=False)
dateDownloaded = !date
dateDownloaded
# Out:
# ['Mi 29. Okt 12:44:59 CET 2014']

# %% [markdown]
# a)
# First five rows of the data set

# %%
boston.head()
# Out:
#       CRIM  ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT   TGT
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# Number of rows and columns

# %%
boston.shape
# Out:
# (506, 14)

# %% [markdown]
# Labels of the columns

# %%
boston.columns
# Out:
# Index([u'CRIM', u'ZN', u'INDUS', u'CHAS', u'NOX', u'RM', u'AGE', u'DIS', u'RAD', u'TAX', u'PTRATIO', u'B', u'LSTAT', u'TGT'], dtype='object')

# %% [markdown]
# Data type of each column

# %%
boston.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# TGT        float64
# dtype: object

# %% [markdown]
# Check whether dataset contains Null values and drop lines containing Null

# %%
print boston.isnull().any()
boston = boston.dropna()
print ""
print boston.isnull().any()
# Out:
# CRIM       False
# ZN         False
# INDUS      False
# CHAS       False
# NOX        False
# RM         False
# AGE        False
# DIS        False
# RAD        False
# TAX        False
# PTRATIO    False
# B          False
# LSTAT      False
# TGT        False
# dtype: bool
#
# CRIM       False
# ZN         False
# INDUS      False
# CHAS       False
# NOX        False
# RM         False
# AGE        False
# DIS        False
# RAD        False
# TAX        False
# PTRATIO    False
# B          False
# LSTAT      False
# TGT        False
# dtype: bool

# %% [markdown]
# Check for duplicates

# %%
boston.duplicated().any()
# Out:
# False

# %% [markdown]
# Compute some statistical values for each column

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# Print scatter matrix

# %%
pd.scatter_matrix(boston, figsize=(14,14), marker='o');

# %% [markdown]
# Categorical variables:
# CHAS
#
# Variables that may be used to determine the value of the house:
# (INDUS, AGE), NOX, RM, LSTAT
#
# Correlations:
# NOX - RM (not correlated)
# NOX - LSTAT (correlated)
# RM - LSTAT (correlated)
#
# Candidates to remove:
# LSTAT: is correlated with both NOX and RM and therefore the information is probably contained in those variables.

# %%
# %install_ext http://raw.github.com/jrjohansson/version_information/master/version_information.py
# Out:
# Installed version_information.py. To use it, type:
#   %load_ext version_information

# %%
# %load_ext version_information
# %version_information numpy,pandas
# Out:
# The version_information extension is already loaded. To reload it, use:
#   %reload_ext version_information
# Software versions
# Python 2.7.8 64bit [GCC 4.9.1]
# IPython 2.3.0
# OS Linux 3.13.0 32 generic x86_64 with Ubuntu 14.10 utopic
# numpy 1.8.2
# pandas 0.14.1
# Wed Oct 29 13:15:12 2014 CET
